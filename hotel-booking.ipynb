# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("hotel_booking.csv")
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
df.shape
# Out:
# (119390, 36)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
df.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
cnt=0
column=''
for i in df:
    tem=df[i].isnull().sum()
    if tem > cnt:
        cnt=tem
        column=i
        print(column,cnt)
# Out:
# children 4
# country 488
# agent 16340
# company 112593

# %%
df["children"].fillna(0,inplace=True) #children null values fill to 0
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df["agent"].fillna(0,inplace=True) #agent null values fill to 0
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               0
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.hotel.unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
df.hotel.value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
print(df.groupby("hotel").sum().adr)  #sum of adr of hotel
# Out:
# hotel
# City Hotel      8353803.24
# Resort Hotel    3803814.36
# Name: adr, dtype: float64

# %%
print(df.groupby("hotel").mean().adr)
print(df.groupby("hotel").median().adr)
# Out:
# hotel
# City Hotel      105.304465
# Resort Hotel     94.952930
# Name: adr, dtype: float64
# hotel
# City Hotel      99.9
# Resort Hotel    75.0
# Name: adr, dtype: float64

# %%
df["is_canceled"].value_counts()  #is_canceled Value indicating if the booking was canceled (1) or not (0)
# Out:
# 0    75166
# 1    44224
# Name: is_canceled, dtype: int64

# %%
df[["customer_type"]][df["is_canceled"]==0] # not canceled customer
# Out:
#        customer_type
# 0          Transient
# 1          Transient
# 2          Transient
# 3          Transient
# 4          Transient
# ...              ...
# 119385     Transient
# 119386     Transient
# 119387     Transient
# 119388     Transient
# 119389     Transient
#
# [75166 rows x 1 columns]

# %%
df[["customer_type"]][df["is_canceled"]==1] # booking canceled customer
# Out:
#        customer_type
# 8          Transient
# 9          Transient
# 10         Transient
# 27         Transient
# 32         Transient
# ...              ...
# 110280     Transient
# 111355     Transient
# 111924     Transient
# 111925     Transient
# 117295     Transient
#
# [44224 rows x 1 columns]

# %%
f=df[df["is_canceled"]==1]     # name and email which canceled booking
f[['name',"email","phone-number"]]
# Out:
#                          name                          email  phone-number
# 8               Steven Murphy        Steven.Murphy54@aol.com  341-726-5787
# 9               Michael Moore     MichaelMoore81@outlook.com  316-648-6176
# 10      Priscilla Collins PhD        PhD.Priscilla74@att.com  833-887-7898
# 27                Jaime Flynn         JaimeFlynn29@gmail.com  549-866-3721
# 32        Reginald Cunningham       Reginald_C57@outlook.com  800-249-2144
# ...                       ...                            ...           ...
# 110280            Robert Webb            RobertWebb@mail.com  517-253-9863
# 111355           Jill Chapman       Jill_Chapman@hotmail.com  946-165-9749
# 111924          Joseph Snyder       Snyder.Joseph@yandex.com  887-156-4050
# 111925              Lisa Berg           Lisa_Berg@yandex.com  348-997-3814
# 117295        Russell Bennett  Russell.Bennett76@hotmail.com  117-040-1415
#
# [44224 rows x 3 columns]

# %%
df.total_of_special_requests.value_counts()
# Out:
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: total_of_special_requests, dtype: int64

# %%
t=df[df["total_of_special_requests"]==5]     
t[['name',"email",'phone-number']]
# Out:
#                           name                          email  phone-number
# 7860             Amanda Harper           Amanda.H66@yahoo.com  864-257-9807
# 11125            Laura Sanders      Sanders_Laura@hotmail.com  120-754-3942
# 14596              Tommy Ortiz            Tommy_O@hotmail.com  377-098-5937
# 14921           Gilbert Miller         Miller.Gilbert@aol.com  806-574-2045
# 14922           Timothy Torres         TTorres@protonmail.com  422-113-4918
# 24630          Jennifer Weaver             Jennifer_W@aol.com  341-150-8437
# 27288           Crystal Horton             Crystal.H@mail.com  736-187-2543
# 27477           Brittney Burke       Burke_Brittney16@att.com  825-860-3212
# 29906          Cynthia Cabrera    Cabrera.Cynthia@xfinity.com  280-973-9357
# 29949              Sarah Floyd              Sarah_F@gmail.com  100-586-7149
# 32267           Michelle Villa         Michelle.Villa@aol.com  494-968-0905
# ...

# %%
t=df[df["total_of_special_requests"]==4]     # name and email which canceled booking
t[['name',"email",'phone-number']]
# Out:
#                       name                           email  phone-number
# 862             John Wyatt              John.Wyatt@att.com  722-068-9547
# 875               Amy Cole             Amy_C24@verizon.com  292-723-7982
# 928     Alexandria Lindsey  Lindsey_Alexandria14@gmail.com  648-279-8407
# 937       Jessica Anderson    Anderson.Jessica@outlook.com  297-735-3046
# 1311         Darlene Smith         Darlene_Smith96@att.com  133-149-2117
# ...                    ...                             ...           ...
# 119248        Tammy Hughes             Tammy_H@outlook.com  992-779-1181
# 119290       Matthew Wyatt       Wyatt.Matthew37@gmail.com  172-705-7652
# 119291        Keith Hunter        Keith_Hunter@xfinity.com  961-034-5781
# 119334         Brent Hines              Brent.H81@zoho.com  713-077-3942
# 119387        Mary Morales        Mary_Morales@hotmail.com  395-518-4100
#
# [340 rows x 3 columns]

# %%
df.arrival_date_year.unique()
# Out:
# array([2015, 2016, 2017])

# %%
df.adults.unique ()
# Out:
# array([ 2,  1,  3,  4, 40, 26, 50, 27, 55,  0, 20,  6,  5, 10])

# %%
df[["adults","children","babies"]].sum()
# Out:
# adults      221636.0
# children     12403.0
# babies         949.0
# dtype: float64

# %%
df['total_person']=df.apply(lambda x : x['adults'] +  x['children'] + x['babies'], axis=1)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...   adr  \
# 0                        0                     0       2  ...   0.0
# ...

# %%
df.total_person.sum()
# Out:
# 234988.0

# %%
df.total_person.sum()/119390*100
# Out:
# 196.8238545941871

# %%
df.customer_type.unique ()
# Out:
# array(['Transient', 'Contract', 'Transient-Party', 'Group'], dtype=object)

# %%
df.customer_type.value_counts()
# Out:
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: customer_type, dtype: int64

# %%
df.country.value_counts()
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# DJI        1
# BWA        1
# HND        1
# VGB        1
# NAM        1
# Name: country, Length: 177, dtype: int64

# %%
df.groupby([df["name"]])["adr"].agg(["max"])
# Out:
#                     max
# name
# Aaron Acevedo    152.10
# Aaron Acosta     115.00
# Aaron Adams      236.10
# Aaron Aguilar     86.00
# Aaron Alexander  171.33
# ...                 ...
# Zoe Rivera        74.00
# Zoe Sanders PhD   75.00
# Zoe Simpson       69.53
# Zoe Stephenson    65.00
# Zoe Wu           140.00
#
# [81503 rows x 1 columns]

# %%
# df.adr.max()
c=df['adr'].idxmax()
df.loc[c,['name','adr']]
# Out:
# name    Daniel Walter
# adr            5400.0
# Name: 48515, dtype: object

# %%
# df.adr.min()
c=df['adr'].idxmin()
df.loc[c,['name','adr']]
# Out:
# name    Chase Santos
# adr            -6.38
# Name: 14969, dtype: object

# %%
df.deposit_type.unique ()
# Out:
# array(['No Deposit', 'Refundable', 'Non Refund'], dtype=object)

# %%
df[["adr","name","phone-number"]][df["deposit_type"]=='Refundable']
# Out:
#           adr              name  phone-number
# 1559    128.0  Anthony Anderson  187-519-5797
# 4737     66.0    Teresa Johnson  625-890-3636
# 4738     66.0        Amy Barker  927-294-0727
# 4739     66.0      Justin Flynn  409-842-9802
# 4740     66.0       Donald West  436-069-1944
# ...       ...               ...           ...
# 79652    85.0     Casey Frazier  792-574-9622
# 79980    63.0       Erin Barker  605-363-5117
# 85497    85.5   Benjamin Bishop  367-289-5054
# 85498    85.5       Andrea Hill  886-054-2285
# 110609   77.0    Russell Morris  572-216-5512
#
# [162 rows x 3 columns]

# %%
df[["adr","name","phone-number"]][df["deposit_type"]=='Non Refund']
# Out:
#            adr              name  phone-number
# 2133     36.05   David Henderson  305-381-5723
# 2134     36.05   Nicole Thompson  705-801-6599
# 2135     36.05      Terry Pierce  608-202-2321
# 2136     36.05    James Martinez  350-812-6928
# 2141     36.05       Joseph Byrd  781-432-4821
# ...        ...               ...           ...
# 95424   106.00    Michael Gordon  822-478-8086
# 95936   106.00  Joshua Robertson  848-760-6442
# 96193    72.25     Julia Dickson  239-701-5198
# 96232    83.83      Jason Jensen  713-286-9416
# 102072   75.00     Emily Johnson  387-265-2812
#
# [14587 rows x 3 columns]

# %%
df[["adr","name","phone-number"]][df["deposit_type"]=='No Deposit']
# Out:
#            adr                name  phone-number
# 0         0.00       Ernest Barnes  669-792-1661
# 1         0.00        Andrea Baker  858-637-6955
# 2        75.00      Rebecca Parker  652-885-2745
# 3        75.00        Laura Murray  364-656-8427
# 4        98.00         Linda Hines  713-226-5883
# ...        ...                 ...           ...
# 119385   96.14     Claudia Johnson  403-092-5582
# 119386  225.43      Wesley Aguilar  238-763-0612
# 119387  157.71        Mary Morales  395-518-4100
# 119388  104.40  Caroline Conley MD  531-528-1017
# 119389  151.20      Ariana Michael  422-804-6403
#
# [104641 rows x 3 columns]

# %%
print(df.groupby("arrival_date_year").max().adr)
# Out:
# arrival_date_year
# 2015     508.0
# 2016    5400.0
# 2017     510.0
# Name: adr, dtype: float64
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.

# %%
df.adr.sum()
# Out:
# 12157617.599999998

# %%
round(df['adr'].mean(),2)  #average daily rate
# Out:
# 101.83

# %%
print(df.groupby("arrival_date_year").sum().adr)
# Out:
# arrival_date_year
# 2015    1917578.62
# 2016    5575764.71
# 2017    4664274.27
# Name: adr, dtype: float64

# %%
df.is_repeated_guest.sum()
# Out:
# 3810

# %%
print(df.groupby("hotel").sum().is_repeated_guest)  #repeated guest sum according to hotel
# Out:
# hotel
# City Hotel      2032
# Resort Hotel    1778
# Name: is_repeated_guest, dtype: int64

# %%
df.assigned_room_type.unique()
# Out:
# array(['C', 'A', 'D', 'E', 'G', 'F', 'I', 'B', 'H', 'P', 'L', 'K'],
#       dtype=object)

# %%
df.assigned_room_type.value_counts()
# Out:
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: assigned_room_type, dtype: int64

# %%
df['total_week_weekend']=df.apply(lambda x : x['stays_in_week_nights'] +  x['stays_in_weekend_nights'], axis=1)

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
df.total_week_weekend.sum()
# Out:
# 409257

# %%
df.groupby("total_week_weekend") ["adr"].agg(["count"])
# Out:
#                     count
# total_week_weekend
# 0                     715
# 1                   21020
# 2                   27643
# 3                   27076
# 4                   17383
# 5                    7784
# 6                    3857
# 7                    8655
# 8                    1161
# 9                     841
# 10                   1139
# 11                    396
# 12                    223
# 13                    142
# 14                    916
# 15                     75
# 16                     40
# 17                     20
# 18                     35
# 19                     22
# 20                     14
# 21                     71
# 22                     14
# 23                      8
# 24                      6
# 25                     37
# 26                      6
# 27                      5
# 28                     35
# 29                     14
# 30                     13
# 33                      3
# 34                      1
# ...

# %%
df["phone-number"].value_counts()
# Out:
# 669-792-1661    1
# 951-326-6252    1
# 446-228-8858    1
# 325-224-7726    1
# 450-566-4040    1
#                ..
# 195-321-7724    1
# 783-942-7089    1
# 425-944-8128    1
# 895-951-9632    1
# 422-804-6403    1
# Name: phone-number, Length: 119390, dtype: int64
